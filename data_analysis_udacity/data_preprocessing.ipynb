# %% [markdown]
# Lembre-se, no entanto, que dados melhores geralmente superam algoritmos melhores, e projetar bons recursos é um grande avanço. E se você tiver um conjunto de dados enorme, qualquer algoritmo de classificação usado pode não importar muito em termos de desempenho de classificação (escolha seu algoritmo com base na velocidade ou facilidade de uso).
#
# E para reiterar o que eu disse acima, se você realmente se preocupa com precisão, você deve definitivamente tentar um monte de classificadores diferentes e selecionar o melhor por validação cruzada.

# %% [markdown]
# Existem diversos atributos não-numéricos para cada registro. Usualmente, algoritmos de aprendizado esperam que os inputs sejam numéricos, o que requer que os atributos não numéricos (chamados de variáveis de categoria) sejam convertidos.
#
# ### Estratégia **one-hot encoding**
#
# Esta estratégia cria uma variável para cada categoria ("dummy") possível de cada atributo não numérico. Por exemplo, assuma que `algumAtributo` possuí três valores possíveis: `A`, `B`, ou `C`. Nós então transformamos este atributo em três novos atributos: `algumAtributo_A`, `algumAtributo_B` e `algumAtributo_C`.
#
#
# |   | algumAtributo |                    | algumAtributo_A | algumAtributo_B | algumAtributo_C |
# | :-: | :-: |                            | :-: | :-: | :-: |
# | 0 |  B  |  | 0 | 1 | 0 |
# | 1 |  C  | ----> one-hot encode ----> | 0 | 0 | 1 |
# | 2 |  A  |  | 1 | 0 | 0 |

# %% [markdown]
# Geralmente, é uma ótima idéia iniciar a análise exploratória, obtendo as estatísticas do conjunto de dados. Eu costumo pegar isso de - - biblioteca Pandas usando o método descrever:<br/>
# `pd.dataframe.describe()`

# %%
# hide_code
from IPython.display import Image
Image('/home/brunocampos01/projetos/data_science/images/modelagem_exploratoria.png')
