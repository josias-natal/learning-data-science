# %% [markdown]
# ## Treinando modelos no scikit learn

# %%
from IPython.display import Image 

Image('/home/brunocampos01/projetos/data_science_machine_learning/tutorial/imagens/models.png')

# %%
import sklearn as sk

# Read the data
# Split the data into X and y
# Define classifier
# Fit classifier

# %% [markdown]
# ### Regressão logística

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()

# %% [markdown]
# ### Redes neurais

# %%
from sklearn.neural_network import MLPClassifier

classifier = MLPClassifier

# %% [markdown]
# ### Árvores de decisão

# %%
from sklearn.ensemble import GradientBoostingClassifier

classifier = GradientBoostingClassifier()

# %% [markdown]
# ### SVM (Máquinas de vetores de suporte)

# %%
from sklearn.svm import SVC

classifier = SVC()

# %% [markdown]
# Depois de instanciar o classificador é necessário **ajustar os dados**.

# %% [markdown]
# ### Exemplos
# Vamos fazer um exemplo do início ao fim, mostrando como ler dados e treinar nosso classificador.

# %%
import pandas
import numpy
from sklearn.linear_model import LogisticRegression

# Read the data
dataframe = pandas.read_csv("data.csv")

# Split the data into X and y
X = numpy.array(data[['x1', 'x2']])
y = numpy.array(data['y'])

# Define a classifier
classifier = LogisticRegression()
classifier.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
from IPython.display import Image 
Image('/home/brunocampos01/projetos/data_science_machine_learning/tutorial/imagens/logistic_regression.png')

# %%
import pandas
import numpy
from sklearn.tree import DecisionTreeClassifier

# Read the data
dataframe = pandas.read_csv("data.csv")

# Split the data into X and y
X = numpy.array(data[['x1', 'x2']])
y = numpy.array(data['y'])

# Define a classifier
classifier = DecisionTreeClassifier()
classifier.fit(X,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from IPython.display import Image 
Image('/home/brunocampos01/projetos/data_science_machine_learning/tutorial/imagens/decision_tree.png')

# %% [markdown]
# Isso nos dá a seguinte fronteira:

# %%
import pandas
import numpy
from sklearn.svm import SVC

# Read the data
dataframe = pandas.read_csv("data.csv")

# Split the data into X and y
X = numpy.array(data[['x1', 'x2']])
y = numpy.array(data['y'])

# Define a classifier
classifier = SVC()
classifier.fit(X,y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
from IPython.display import Image 
Image('/home/brunocampos01/projetos/data_science_machine_learning/tutorial/imagens/svc.png')
